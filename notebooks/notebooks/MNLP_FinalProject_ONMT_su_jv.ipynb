# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Assignment 2/FinalProject'
! ls
# Out:
# /content/drive/.shortcut-targets-by-id/1odfm_Owe29caFTZxRZs1d-zlWkU2-G7x/Assignment 2/FinalProject
#  eng_ind.yaml   model_step_38500.pt   something.sh   train.min
#  ind_eng.yaml   model_step_8500.pt    test.ind	     valid.ind
#  ind_min.yaml  'pred_1000 (1).txt'    test.min	     valid.min
#  min_ind.yaml   pred_1000.txt	      train.ind

# %%
# %cd /content/
# !git clone https://github.com/fajri91/minangNLP.git
# Out:
# /content
# Cloning into 'minangNLP'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 91 (delta 26), reused 47 (delta 6), pack-reused 0
# Unpacking objects: 100% (91/91), done.

# %%
# %cd /content/
# !git clone https://github.com/OpenNMT/OpenNMT-py.git
# %cd OpenNMT-py
# !python setup.py install
# Out:
# /content
# Cloning into 'OpenNMT-py'...
# remote: Enumerating objects: 17675, done.
# remote: Counting objects: 100% (631/631), done.
# remote: Compressing objects: 100% (356/356), done.
# remote: Total 17675 (delta 372), reused 467 (delta 265), pack-reused 17044
# Receiving objects: 100% (17675/17675), 273.82 MiB | 16.80 MiB/s, done.
# Resolving deltas: 100% (12672/12672), done.
# /content/OpenNMT-py
# running install
# running bdist_egg
# running egg_info
# creating OpenNMT_py.egg-info
# writing OpenNMT_py.egg-info/PKG-INFO
# writing dependency_links to OpenNMT_py.egg-info/dependency_links.txt
# writing entry points to OpenNMT_py.egg-info/entry_points.txt
# writing requirements to OpenNMT_py.egg-info/requires.txt
# writing top-level names to OpenNMT_py.egg-info/top_level.txt
# writing manifest file 'OpenNMT_py.egg-info/SOURCES.txt'
# adding license file 'LICENSE.md'
# writing manifest file 'OpenNMT_py.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# ...

# %%
% cd /content/minangNLP
# Out:
# /content/minangNLP

# %%
! pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 104 kB 32.9 MB/s
# ...
#      |████████████████████████████████| 103 kB 65.9 MB/s
# ...
#      |████████████████████████████████| 151 kB 59.8 MB/s
# ...
#      |████████████████████████████████| 111 kB 63.4 MB/s
# ...
#      |████████████████████████████████| 157 kB 50.1 MB/s
# ...
#      |████████████████████████████████| 400 kB 67.6 MB/s
# ...
#      |████████████████████████████████| 82 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 74.7 MB/s
# ...
#      |████████████████████████████████| 829 kB 63.0 MB/s
# ...
#      |████████████████████████████████| 89 kB 10.1 MB/s
# ...
#      |████████████████████████████████| 2.7 MB 74.0 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 51.0 MB/s
# ...
#      |████████████████████████████████| 292 kB 70.4 MB/s
# ...
#      |████████████████████████████████| 58 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 118 kB 70.3 MB/s
# ...
#      |████████████████████████████████| 782 kB 62.5 MB/s
# ...
#      |████████████████████████████████| 121 kB 71.6 MB/s
# ...

# %%
# !pip install bpe
# Out:
# ...
#   Using cached bpe-1.0-py3-none-any.whl (6.8 kB)
# ...
#      |████████████████████████████████| 381 kB 30.8 MB/s
# ...
#      |████████████████████████████████| 14.4 MB 30.7 MB/s
# ...
#      |████████████████████████████████| 843 kB 47.5 MB/s
# ...

# %%
# %cd '/content/drive/My Drive/Assignment 2/FinalProject/configs/'
# !onmt_build_vocab -config sun_ind.yaml -n_sample 10000
# Out:
# /content/drive/.shortcut-targets-by-id/1odfm_Owe29caFTZxRZs1d-zlWkU2-G7x/Assignment 2/FinalProject/configs
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-04-15 21:27:31,178 INFO] Counter vocab from 10000 samples.
# [2022-04-15 21:27:31,178 INFO] Build vocab on 10000 transformed examples/corpus.
# [2022-04-15 21:27:31,189 INFO] corpus_1's transforms: TransformPipe()
# [2022-04-15 21:27:32,997 INFO] Counters src:17264
# [2022-04-15 21:27:32,997 INFO] Counters tgt:10723

# %%
# !onmt_train -config sun_ind.yaml
# Out:
# [2022-04-15 21:28:22,755 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-04-15 21:28:22,757 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-04-15 21:28:22,757 INFO] Missing transforms field for valid data, set to default: [].
# [2022-04-15 21:28:22,758 INFO] Parsed 2 corpora from -data.
# [2022-04-15 21:28:22,758 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-04-15 21:28:22,758 INFO] Loading vocab from text file...
# [2022-04-15 21:28:22,758 INFO] Loading src vocabulary from /content/translation/example.vocab.src
# [2022-04-15 21:28:22,790 INFO] Loaded src vocab has 17264 tokens.
# [2022-04-15 21:28:22,797 INFO] Loading tgt vocabulary from /content/translation/example.vocab.tgt
# [2022-04-15 21:28:22,816 INFO] Loaded tgt vocab has 10723 tokens.
# [2022-04-15 21:28:22,821 INFO] Building fields with vocab in counters...
# [2022-04-15 21:28:22,833 INFO]  * tgt vocab size: 10727.
# ...

# %%
# %cd '/content/drive/My Drive/Assignment 2/FinalProject'
# Out:
# /content/drive/.shortcut-targets-by-id/1odfm_Owe29caFTZxRZs1d-zlWkU2-G7x/Assignment 2/FinalProject

# %%
# !onmt_translate -model model_step_21500.pt -src '/content/drive/My Drive/Assignment 2/FinalProject/data/su-id/su_test.txt' -output /content/pred_1000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 194: ['Saterusna', ',', 'dulur-dulur', ',', 'simkuring', 'aya', 'pamenta!', 'Demi', 'pajenengan', 'Gusti', 'Jungjunan', 'urang', ',', 'Isa', 'Al', 'Masih', ',', 'muga', 'aranjeun', 'tetep', 'sauyunan', ',', 'ulah', 'pakia-kia.', 'Sing', 'tetep', 'satunggal', 'dina', 'pikir', 'jeung', 'pangrasa.']
# PRED 194: Sebab itu saudara-saudara , saudara-saudara , pilihlah suatu contoh yang penuh kesabaran kepada kamu , sehingga dengan demikian aku menyatakannya ,
# PRED SCORE: -9.2680
#
# [2022-04-15 22:15:18,482 INFO]
# SENT 195: ['Ku', 'sabab', 'eta', ',', 'anu', 'nyaho', 'kana', 'lampah', 'hade', ',', 'tapi', 'teu', 'prak', 'dipilampah;', 'eta', 'teh', 'dosa!']
# PRED 195: Karena itu juga , bukan hanya bagi orang yang ada di situ , tetapi juga hidup yang diam di dalam aku.
# PRED SCORE: -7.1773
#
# [2022-04-15 22:15:18,482 INFO]
# ...

# %%
# %cd '/content/drive/My Drive/Assignment 2/FinalProject/configs/'
# !onmt_build_vocab -config ind_sun.yaml -n_sample 10000
# Out:
# /content/drive/.shortcut-targets-by-id/1odfm_Owe29caFTZxRZs1d-zlWkU2-G7x/Assignment 2/FinalProject/configs
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-04-15 22:32:07,434 INFO] Counter vocab from 10000 samples.
# [2022-04-15 22:32:07,434 INFO] Build vocab on 10000 transformed examples/corpus.
# [2022-04-15 22:32:07,445 INFO] corpus_1's transforms: TransformPipe()
# [2022-04-15 22:32:07,651 INFO] Counters src:10723
# [2022-04-15 22:32:07,651 INFO] Counters tgt:17264
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_build_vocab", line 33, in <module>
#     sys.exit(load_entry_point('OpenNMT-py==2.2.0', 'console_scripts', 'onmt_build_vocab')())
#   File "/usr/local/lib/python3.7/dist-packages/OpenNMT_py-2.2.0-py3.7.egg/onmt/bin/build_vocab.py", line 71, in main
#     build_vocab_main(opts)
#   File "/usr/local/lib/python3.7/dist-packages/OpenNMT_py-2.2.0-py3.7.egg/onmt/bin/build_vocab.py", line 55, in build_vocab_main
# ...

# %%
# !onmt_train -config ind_sun.yaml
# Out:
# [2022-04-15 22:37:20,372 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-04-15 22:37:20,373 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-04-15 22:37:20,373 INFO] Missing transforms field for valid data, set to default: [].
# [2022-04-15 22:37:20,374 INFO] Parsed 2 corpora from -data.
# [2022-04-15 22:37:20,374 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-04-15 22:37:20,374 INFO] Loading vocab from text file...
# [2022-04-15 22:37:20,374 INFO] Loading src vocabulary from /content/translation/id-su/example.vocab.src
# [2022-04-15 22:37:20,395 INFO] Loaded src vocab has 10723 tokens.
# [2022-04-15 22:37:20,400 INFO] Loading tgt vocabulary from /content/translation/id-su/example.vocab.tgt
# [2022-04-15 22:37:20,432 INFO] Loaded tgt vocab has 17264 tokens.
# [2022-04-15 22:37:20,439 INFO] Building fields with vocab in counters...
# ...

# %%
# !onmt_translate -model '/content/translation/id-su/model_step_13000.pt' -src '/content/drive/My Drive/Assignment 2/FinalProject/data/su-id/id_test.txt' -output /content/pred_1000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 194: ['Tetapi', 'aku', 'menasihatkan', 'kamu', ',', 'saudara-saudara', ',', 'demi', 'nama', 'Tuhan', 'kita', 'Yesus', 'Kristus', ',', 'supaya', 'kamu', 'seia', 'sekata', 'dan', 'jangan', 'ada', 'perpecahan', 'di', 'antara', 'kamu', ',', 'tetapi', 'sebaliknya', 'supaya', 'kamu', 'erat', 'bersatu', 'dan', 'sehati', 'sepikir.']
# PRED 194: Nu dipake simkuring mah , agul teh , nya eta Isa Al Masih , Gusti Jungjunan urang , jeung ku Isa Al Masih , nu matak aranjeun mah , muga aranjeun ulah teu gagal.
# PRED SCORE: -14.3977
#
# [2022-04-15 23:18:32,859 INFO]
# SENT 195: ['Jadi', 'jika', 'seorang', 'tahu', 'bagaimana', 'ia', 'harus', 'berbuat', 'baik', ',', 'tetapi', 'ia', 'tidak', 'melakukannya', ',', 'ia', 'berdosa.']
# PRED 195: Atuh eta teh , pikeun jadi saksi pikeun maranehna , ari anjeunna mah geus teu aya.
# PRED SCORE: -8.8155
#
# [2022-04-15 23:18:32,859 INFO]
# ...

# %%
! cp '/content/translation/id-su/model_step_13000.pt' '/content/drive/My Drive/Assignment 2/FinalProject/'

# %%
# %cd '/content/drive/My Drive/Assignment 2/FinalProject/configs/'
# !onmt_build_vocab -config jav_ind.yaml -n_sample 10000
# Out:
# /content/drive/.shortcut-targets-by-id/1odfm_Owe29caFTZxRZs1d-zlWkU2-G7x/Assignment 2/FinalProject/configs
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-04-15 23:26:02,585 INFO] Counter vocab from 10000 samples.
# [2022-04-15 23:26:02,585 INFO] Build vocab on 10000 transformed examples/corpus.
# [2022-04-15 23:26:02,596 INFO] corpus_1's transforms: TransformPipe()
# [2022-04-15 23:26:04,304 INFO] Counters src:13668
# [2022-04-15 23:26:04,305 INFO] Counters tgt:10680

# %%
# !onmt_train -config jav_ind.yaml
# Out:
# [2022-04-15 23:26:27,779 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-04-15 23:26:27,780 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-04-15 23:26:27,781 INFO] Missing transforms field for valid data, set to default: [].
# [2022-04-15 23:26:27,781 INFO] Parsed 2 corpora from -data.
# [2022-04-15 23:26:27,782 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-04-15 23:26:27,782 INFO] Loading vocab from text file...
# [2022-04-15 23:26:27,782 INFO] Loading src vocabulary from /content/translation/jv-id/example.vocab.src
# [2022-04-15 23:26:27,808 INFO] Loaded src vocab has 13668 tokens.
# [2022-04-15 23:26:27,814 INFO] Loading tgt vocabulary from /content/translation/jv-id/example.vocab.tgt
# [2022-04-15 23:26:27,832 INFO] Loaded tgt vocab has 10680 tokens.
# [2022-04-15 23:26:27,836 INFO] Building fields with vocab in counters...
# ...

# %%
! cp '/content/translation/jv-id/model_step_51500.pt' '/content/drive/My Drive/Assignment 2/FinalProject/'

# %%
# !onmt_translate -model '/content/translation/jv-id/model_step_51500.pt' -src '/content/drive/My Drive/Assignment 2/FinalProject/data/jv-id/jv_test.txt' -output /content/pred_1000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 194: ['mung', 'ana', 'Allah', 'siji', ',', 'Ramané', 'wong', 'kabèh', ',', 'Allah', 'kang', 'mengku', 'samubarang', ',', 'lumantar', 'samubarang', ',', 'lan', 'ana', 'ing', 'samubarang.']
# PRED 194: hanya satu Allah , yaitu Bapa dari semua orang , Allah yang setia dalam segala sesuatu , dan di dalam segala sesuatu.
# PRED SCORE: -1.7344
#
# [2022-04-16 01:00:15,194 INFO]
# SENT 195: ['Aku', 'kudu', 'kabaptis', ',', 'lan', 'sapira', 'gedhéné', 'kasusahaning', 'atiku', ',', 'sadurungé', 'iku', 'kelakon!']
# PRED 195: Aku harus dibaptis , dan terlebih dahulu hari raya hatiku , sebelum itu benar:
# PRED SCORE: -3.3391
#
# [2022-04-16 01:00:15,194 INFO]
# SENT 196: ['Apa', 'kowé', 'arep', 'ngrèmèhaké', 'lubèring', 'kamirahan', 'sarta', 'sabar-sarèhé', 'Allah?', 'Apa', 'kowé', 'ora', 'mangerti', 'menawa', 'kamirahané', 'Allah', 'iku', 'nuntun', 'kowé', 'marang', 'pamratobat?']
# ...

# %%
# %cd '/content/drive/My Drive/Assignment 2/FinalProject/configs/'
# !onmt_build_vocab -config ind_jav.yaml -n_sample 10000
# Out:
# /content/drive/.shortcut-targets-by-id/1odfm_Owe29caFTZxRZs1d-zlWkU2-G7x/Assignment 2/FinalProject/configs
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-04-16 01:04:54,528 INFO] Counter vocab from 10000 samples.
# [2022-04-16 01:04:54,528 INFO] Build vocab on 10000 transformed examples/corpus.
# [2022-04-16 01:04:54,540 INFO] corpus_1's transforms: TransformPipe()
# [2022-04-16 01:04:54,746 INFO] Counters src:10680
# [2022-04-16 01:04:54,746 INFO] Counters tgt:13668

# %%
# !onmt_train -config ind_jav.yaml
# Out:
# [2022-04-16 01:05:49,942 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-04-16 01:05:49,943 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-04-16 01:05:49,943 INFO] Missing transforms field for valid data, set to default: [].
# [2022-04-16 01:05:49,944 INFO] Parsed 2 corpora from -data.
# [2022-04-16 01:05:49,944 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-04-16 01:05:49,944 INFO] Loading vocab from text file...
# [2022-04-16 01:05:49,945 INFO] Loading src vocabulary from /content/translation/id-jv/example.vocab.src
# [2022-04-16 01:05:49,965 INFO] Loaded src vocab has 10680 tokens.
# [2022-04-16 01:05:49,970 INFO] Loading tgt vocabulary from /content/translation/id-jv/example.vocab.tgt
# [2022-04-16 01:05:49,997 INFO] Loaded tgt vocab has 13668 tokens.
# [2022-04-16 01:05:50,004 INFO] Building fields with vocab in counters...
# ...

# %%
! cp '/content/translation/id-jv/model_step_20000.pt' '/content/drive/My Drive/Assignment 2/FinalProject/'

# %%
# !onmt_translate -model '/content/translation/id-jv/model_step_20000.pt' -src '/content/drive/My Drive/Assignment 2/FinalProject/data/jv-id/id_test.txt' -output /content/pred_1000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 194: ['satu', 'Allah', 'dan', 'Bapa', 'dari', 'semua', ',', 'Allah', 'yang', 'di', 'atas', 'semua', 'dan', 'oleh', 'semua', 'dan', 'di', 'dalam', 'semua.']
# PRED 194: Allah sarta Rama saka sakèhing wong , Allah kang ana ing samubarang kabèh lan déning keparengé apadéné sakèhing pangwasa lan ing geni.
# PRED SCORE: -5.4409
#
# [2022-04-16 01:46:47,797 INFO]
# SENT 195: ['Aku', 'harus', 'menerima', 'baptisan', ',', 'dan', 'betapakah', 'susahnya', 'hati-Ku', ',', 'sebelum', 'hal', 'itu', 'berlangsung!']
# PRED 195: Aku bisa nampani tuladha , lan nggayuha pangangen-angen , sadurungé iku nyata.
# PRED SCORE: -9.1387
#
# [2022-04-16 01:46:47,797 INFO]
# SENT 196: ['Maukah', 'engkau', 'menganggap', 'sepi', 'kekayaan', 'kemurahan-Nya', ',', 'kesabaran-Nya', 'dan', 'kelapangan', 'hati-Nya?', 'Tidakkah', 'engkau', 'tahu', ',', 'bahwa', 'maksud', 'kemurahan', 'Allah', 'ialah', 'menuntun', 'engkau', 'kepada', 'pertobatan?']
# ...
